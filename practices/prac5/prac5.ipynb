# %% [markdown]
# <a href="https://colab.research.google.com/github/ska-19/RL25/blob/prac5_Kirill_Semenkovich/practices/prac5/prac5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
    import google.colab
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB = True
except:
    COLAB = False

# !pip install gymnasium==0.29.1 vizdoom==1.2.4 wandb==0.19.1
# Out:
# Mounted at /content/drive
# Requirement already satisfied: gymnasium==0.29.1 in /usr/local/lib/python3.12/dist-packages (0.29.1)
# Requirement already satisfied: vizdoom==1.2.4 in /usr/local/lib/python3.12/dist-packages (1.2.4)
# Requirement already satisfied: wandb==0.19.1 in /usr/local/lib/python3.12/dist-packages (0.19.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium==0.29.1) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium==0.29.1) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium==0.29.1) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium==0.29.1) (0.0.4)
# Requirement already satisfied: pygame>=2.1.3 in /usr/local/lib/python3.12/dist-packages (from vizdoom==1.2.4) (2.6.1)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /usr/local/lib/python3.12/dist-packages (from wandb==0.19.1) (8.3.0)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from wandb==0.19.1) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb==0.19.1) (3.1.45)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from wandb==0.19.1) (4.5.0)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<6,>=3.19.0 in /usr/local/lib/python3.12/dist-packages (from wandb==0.19.1) (5.29.5)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb==0.19.1) (5.9.5)
# Requirement already satisfied: pydantic<3,>=2.6 in /usr/local/lib/python3.12/dist-packages (from wandb==0.19.1) (2.11.10)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from wandb==0.19.1) (6.0.3)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb==0.19.1) (2.32.4)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb==0.19.1) (2.42.1)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.12/dist-packages (from wandb==0.19.1) (1.3.7)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from wandb==0.19.1) (75.2.0)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from docker-pycreds>=0.4.0->wandb==0.19.1) (1.17.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb==0.19.1) (4.0.12)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.6->wandb==0.19.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.6->wandb==0.19.1) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.6->wandb==0.19.1) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb==0.19.1) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb==0.19.1) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb==0.19.1) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb==0.19.1) (2025.10.5)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb==0.19.1) (5.0.2)

# %%
import json
import math
import random
import sys
import os
import time
from collections import deque
from typing import Dict, Type, Any, Tuple, NamedTuple, Optional, Union, Generator, List

import gymnasium as gym
import gymnasium.spaces as spaces
from gymnasium.vector import AsyncVectorEnv, SyncVectorEnv
from gymnasium.wrappers import ResizeObservation, GrayScaleObservation, RecordEpisodeStatistics, TransformReward, \
    FrameStack
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn.functional as F
from torch import nn
from torch.distributions import Categorical
import vizdoom
from vizdoom import gymnasium_wrapper

try:
    import wandb
    WANDB_IS_AVAILABLE = True
except ImportError:
    WANDB_IS_AVAILABLE = False

os.environ["WANDB_API_KEY"] = "e97ffa4c776cbfb2c0fc0c8b5c97e875139c1d42"

# %% [markdown]
# # Градиент стратегии: REINFORCE
#
# Обозначения:
# - $s$ - состояние, $r$ - вознаграждение, $a$ - действие
# - Условное распределение действий $\pi(a | s)$ - стратегия агента
# - $\tau$ - траектория: $(s_0, r_0, a_0), \dots, (s_T, r_T, a_T)$
# - Отдача $G(\tau) = \sum_{t = 0} ^ T r_t \gamma ^ t$
# - $G_t = r_t + r_{t + 1} \gamma + \dots + r_{T} \gamma ^ {T - t}$
# - Функция полезности состояний: $V(s_{t}) = \mathbb{E}[G_t]$
# - Функция полезности действий: $Q(s_t, a_t) = \mathbb{E}[r_t + \gamma V(s_{t + 1}) | a_t]$
#
# В некоторых задачах для нахождения удовлетворительной стратегии необязательно в точности знать структуру всей среды. Например, в задаче поднятия кубика робототехнической рукой вместо точной аппроксимации полезности $Q(s,a)$ достаточно знать, что выгоднее: двигаться вправо, если кубик справа, и влево в ином случае. С этим же наблюдением связано и предположение, что задача поиска удовлетворительной стратегии проще, нежели задача точной оценки функции полезности.
#
# В данном семинаре познакомимся с простейшим методом прямой оптимизации стратегии REINFORCE, в котором параметры, задающие вероятностную стратегию, изменяются в соответствии с градиентом математического ожидания отдач:
#
# $$J(\theta)= \mathbb{E}[G(\tau)],$$
#
# $$\theta \leftarrow \theta +\alpha \nabla_{\theta} J(\theta),$$
#
# В первом выражении математическое ожидание берется по распределениям начальных состояний, вероятностным функциям переходов и вознаграждений среды, а также по вероятностной стратегии агента $\pi_\theta$. Благодаря теореме о существовании стационарного распределения марковской цепи, это выражение может быть переписано через стационарное распределение $d^\pi$ посещения состояний в среде:
#
# $$J(\theta)= \mathbb{E}_{s \sim d^\pi}[V^{\pi}(s)] = \mathbb{E}_{s \sim d^\pi, a \sim \pi(s)} [Q^{\pi}(s, a)] =: \mathbb{E}_\pi [Q^{\pi}(s, a)].$$
#
# Метод REINFORCE также использует теорему о градиенте стратегии, на основе которой построено целое семейство алгоритмов прямой оптимизации стратегии и актор-критиков. Теорема о градиенте стратегии связывает градиент целевой функции $J$ и градиент самой стратегии:
#
# $$\nabla_\theta J(\theta) = \mathbb{E}_\pi [Q^\pi(s, a) \nabla_\theta \ln \pi_\theta(a \vert s)]$$
#
# Для оценки полезности действий $Q^\pi(s, a)$ REINFORCE использует несмещенную Монте-Карло оценку на основе полученных в среде отдач $G_t$ (за некоторое фиксированное число эпизодов в среде). С учетом этого обновление весов осуществляется по правилу:
#
# $$\nabla_\theta J(\theta) = \mathbb{E}_\pi [G_t \nabla_\theta \ln \pi_\theta(a_t \vert s_t)]$$
#
# Более подробное (но все равно короткое) описание градиента стратегии, и в частности REINFORCE, можно посмотреть в [блоге Lilian Weng из OpenAI](https://lilianweng.github.io/posts/2018-04-08-policy-gradient/#policy-gradient), либо полноценно разобраться в соответствующей секции классического учебника Саттона и Барто.

# %% [markdown]
# ### Environment: Vizdoom
# Среда для экспериментов: **Vizdoom**. Задача: **VizdoomCorridor-v0**.
#
# Карта представляет собой коридор со стреляющими противниками по обеим сторонам. Зелёная броня размещена на противоположном конце коридора. Цель агента — добраться до предмета. Награда пропорциональна (отрицательна или положительна) изменению расстояния между игроком и жилетом.
# - Вознаграждение: +dX за приближение к броне, -dX за отдаление от брони, -100 за смерть.
# - Агенту доступны 7 действий: движение вперед/назад/влево/вправо, поворот влево/вправо, стрельба.
# - Ограничение по времени: 2100 шагов
#
# Для ускорения обучения агента рассматриваем самый простой уровень сложности `doom_skill = 1`.

# %%
def create_vizdoom_config(verbose=False):
    # Создаёт файл сценария VizdoomCorridor с уровнем сложности doom_skill = 1

    deadly_corridor_doom_skill_1 = """
    # Lines starting with # are treated as comments (or with whitespaces+#).
    # It doesn't matter if you use capital letters or not.
    # It doesn't matter if you use underscore or camel notation for keys, e.g. episode_timeout is the same as episodeTimeout.
    """
    deadly_corridor_doom_skill_1 += f"\ndoom_scenario_path = {os.path.relpath(os.path.dirname(vizdoom.__file__))}/scenarios/deadly_corridor.wad\n"
    deadly_corridor_doom_skill_1 += """
    # Skill 5 is recommended for the scenario to be a challenge.
    doom_skill = 1

    # Rewards
    death_penalty = 100
    #living_reward = 0

    # Rendering options
    screen_resolution = RES_320X240
    screen_format = CRCGCB
    render_hud = true
    render_crosshair = false
    render_weapon = true
    render_decals = false
    render_particles = false
    window_visible = true

    episode_timeout = 2100

    # Available buttons
    available_buttons =
      {
        MOVE_LEFT
        MOVE_RIGHT
        ATTACK
        MOVE_FORWARD
        MOVE_BACKWARD
        TURN_LEFT
        TURN_RIGHT
      }

    # Game variables that will be in the state
    available_game_variables = { HEALTH }

    mode = PLAYER
    """

    config_file_name = f'deadly_corridor_doom-skill-1.cfg'
    with open(config_file_name, 'w') as file_obj:
        print(deadly_corridor_doom_skill_1, file=file_obj)

    if verbose:
        print(deadly_corridor_doom_skill_1)

    return os.path.realpath(config_file_name)


def source_env_info():
    config_file_path = create_vizdoom_config()
    env = gym.make('VizdoomCorridor-v0', **{'scenario_file': config_file_path})
    obs, _ = env.reset()
    plt.imshow(obs['screen'])
    plt.show()
    print(env.env.env.spec.kwargs)

source_env_info()
# Out:
# /usr/local/lib/python3.12/dist-packages/vizdoom/gymnasium_wrapper/base_gymnasium_env.py:84: UserWarning: Detected screen format CRCGCB. Only RGB24 and GRAY8 are supported in the Gymnasium wrapper. Forcing RGB24.
#   warnings.warn(
# {'scenario_file': '/content/deadly_corridor_doom-skill-1.cfg'}

# %% [markdown]
# ### Wrappers

# %%
class ImageExtractorWrapper(gym.ObservationWrapper):
    def __init__(self, env):
        super().__init__(env)
        self.observation_space = env.observation_space['screen']

    def observation(self, observation: Dict) -> np.ndarray:
        return observation['screen']


def make_env():
    config_file_path = create_vizdoom_config()
    env = gym.make('VizdoomCorridor-v0', **{'scenario_file': config_file_path})
    env = ImageExtractorWrapper(env)
    env = GrayScaleObservation(env)
    env = ResizeObservation(env, shape=84)
    env = FrameStack(env, num_stack=3)
    env = RecordEpisodeStatistics(env)
    env = TransformReward(env, f=lambda reward: reward / 100.)

    return env


def wrapped_env_info():
    config_file_path = create_vizdoom_config()
    env = make_env()
    env.reset()
    terminated = False
    while not terminated:
        obs, reward, terminated, truncated, info = env.step(env.action_space.sample())

    fig, axes = plt.subplots(1, 3, figsize=(12, 3))
    for ax, frame in zip(axes, obs):
        ax.imshow(frame, cmap='gray')

    print('Наблюдение - стек из 3х последовательных изображений 84х84 в оттенках серого, shape:', obs.shape)
    plt.show()
    print('info на последнем шаге содержит статистику эпизода: r - суммарное вознаграждение, l - длина эпизода, t - продолжительность эпизода в секундах\n', info)

DEMO_WRAPPED_ENV = True
if DEMO_WRAPPED_ENV:
    wrapped_env_info()
# Out:
# Наблюдение - стек из 3х последовательных изображений 84х84 в оттенках серого, shape: (3, 84, 84)
# info на последнем шаге содержит статистику эпизода: r - суммарное вознаграждение, l - длина эпизода, t - продолжительность эпизода в секундах
#  {'episode': {'r': array([-86.2357], dtype=float32), 'l': array([524], dtype=int32), 't': array([1.663147], dtype=float32)}}

# %% [markdown]
# ### Misc

# %%
def set_seed_everywhere(seed: int, using_cuda: bool = False) -> None:
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)

    if using_cuda:
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False

# %% [markdown]
# # 1 REINFORCE

# %% [markdown]
# ### Policy
# Основные компоненты ReinforcePolicy:
# - `features_extractor` - свёрточный энкодер, кодирующий изображения в латентный вектор
# - `action_net` - полносвязный слой, который выдаёт логиты действий для предсказания вероятностей

# %% [markdown]
# ![policy](data:image/png;base64,...)

# %%
class Encoder(nn.Module):
    def __init__(
            self,
            observation_space: gym.Space,
            features_dim: int = 512,
    ) -> None:
        super().__init__()
        self.features_dim = features_dim
        n_input_channels = observation_space.shape[0]
        self.cnn = nn.Sequential(
            nn.Conv2d(n_input_channels, 32, kernel_size=8, stride=4, padding=0),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=4, stride=2, padding=0),
            nn.ReLU(),
            nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=0),
            nn.ReLU(),
            nn.Flatten(),
        )

        with torch.no_grad():
            n_flatten = self.cnn(torch.as_tensor(observation_space.sample()[None]).float()).shape[1]

        self.linear = nn.Sequential(nn.Linear(n_flatten, features_dim), nn.ReLU())

    def forward(self, observations: torch.Tensor) -> torch.Tensor:
        return self.linear(self.cnn(observations))


class ReinforcePolicy(nn.Module):
    def __init__(self, observation_space: gym.Space, action_space: gym.Space, lr: float,
                 optimizer_class: Type[torch.optim.Optimizer] = torch.optim.RMSprop,
                 optimizer_kwargs: Dict[str, Any] = {'eps': 1e-5},):
        super().__init__()
        self.observation_space = observation_space
        self.action_space = action_space
        self.lr = lr
        self.optimizer_class = optimizer_class
        self.optimizer_kwargs = dict(optimizer_kwargs)
        self.features_extractor = self.make_features_extractor()
        self.action_net = nn.Linear(self.features_extractor.features_dim, self.action_space.n)
        self.optimizer = self.optimizer_class(self.parameters(), lr=self.lr, **self.optimizer_kwargs)

    def make_features_extractor(self):
        return Encoder(self.observation_space)

    def extract_features(self, obs: torch.Tensor) -> torch.Tensor:
        obs = obs.float() / 255.
        features = self.features_extractor(obs)

        return features

    def forward(self, obs: torch.Tensor, deterministic: bool = False) -> Dict[str, torch.Tensor]:
        features = self.extract_features(obs)

        action_logits = self.action_net(features)
        distribution = Categorical(logits=action_logits)
        actions = distribution.mode() if deterministic else distribution.sample()
        actions = actions.reshape((-1, *self.action_space.shape))

        return {'features': features, 'action': actions}

    def evaluate_actions(self, obs: torch.Tensor, actions_taken: torch.Tensor) -> Dict[str, torch.Tensor]:
        features = self.extract_features(obs)
        action_logits = self.action_net(features)
        distribution = Categorical(logits=action_logits)
        log_prob = distribution.log_prob(actions_taken)
        entropy = distribution.entropy()

        return {'features': features, 'log_prob': log_prob, 'entropy': entropy}

    def set_training_mode(self, mode: bool) -> None:
        self.train(mode)

# %% [markdown]
# ### Buffer
# В буфере хранятся траектории, собранные агентом. Также в буфере производится вычисление частичных отдач по траекториям.

# %%
class BufferSamples(NamedTuple):
    observations: torch.Tensor
    actions: torch.Tensor
    returns: torch.Tensor


class Buffer:
    def __init__(
            self,
            gamma: float = 0.99,
            device: Union[torch.device, str] = "cpu",
    ):
        self.device = torch.device(device)
        self.gamma = gamma
        self.observations = None
        self.actions = None
        self.rewards = None
        self.returns = None

    def reset(self) -> None:
        self.observations = []
        self.actions = []
        self.rewards = []
        self.returns = None

    def size(self) -> int:
        return len(self.actions)

    def add(
            self,
            obs: np.ndarray,
            action: int,
            reward: float,
    ) -> None:
        self.observations.append(obs)
        self.actions.append(action)
        self.rewards.append(reward)

    def to_torch(self, array: np.ndarray) -> torch.Tensor:
        return torch.tensor(array, device=self.device)

    def _get_samples(
            self,
            batch_inds: np.ndarray,
    ) -> BufferSamples:
        observations = self.to_torch(self.observations[batch_inds])
        actions = self.to_torch(self.actions[batch_inds])
        returns = self.to_torch(self.returns[batch_inds])

        return BufferSamples(observations=observations, actions=actions, returns=returns)

    def get(self) -> BufferSamples:
        buffer_size = self.size()
        indices = np.random.permutation(buffer_size)
        self.observations = np.asarray(self.observations)
        self.actions = np.asarray(self.actions)
        self.returns = np.asarray(self.returns, dtype=np.float32)

        return self._get_samples(indices)

    def compute_returns(self) -> None:
        returns = [None] * len(self.rewards)
        reward_to_go = 0
        for step in reversed(range(len(self.rewards))):
            reward_to_go = self.rewards[step] + self.gamma * reward_to_go
            returns[step] = reward_to_go

        self.returns = returns

# %% [markdown]
# ### Обучение стратегии по методу REINFORCE
# - Метод `learn`: реализует основной цикл RL-обучения: чередование фазы сбора данных (траекторий) агентом в среде - `collect_rollouts` и фазы обучения агента - `train`.
# - Метод `collect_rollouts`: агент выполняет действия в среде согласно текущей стратегии, собирая триплеты **<observation, action, reward>** в буфер
# - Метод `train`: обучение на собранных данных. Функция потерь состоит из двух слагаемых: градиент стратегии и энтропийная регуляризация. Энтропийная регуляризация делает стратегию более стохастичной, т.е. более устойчивой к шуму, помогает исследовать среду, предотвращает сходимость к субоптимальному решению (особенно в средах с дискретными действиями)

# %% [markdown]
# ![learn](data:image/png;base64,...)

# %% [markdown]
# ![reinforce](data:image/png;base64,...)

# %%
class Reinforce:
    def __init__(
            self,
            env: gym.Env,
            learning_rate: float = 2.5e-4,
            gamma: float = 0.99,
            ent_coef: float = 0.001,
            max_grad_norm: float = 0.5,
            stats_window_size: int = 10,
            policy_class: Type[ReinforcePolicy] = ReinforcePolicy,
            policy_kwargs: Optional[Dict[str, Any]] = None,
            buffer_class: Type[Buffer] = Buffer,
            buffer_kwargs: Optional[Dict[str, Any]] = None,
            seed: Optional[int] = None,
            device: Union[torch.device, str] = "cuda",
    ):
        self.device = device if isinstance(device, torch.device) else torch.device(device)
        print(f"Using {self.device} device")

        self.policy_kwargs = {} if policy_kwargs is None else policy_kwargs

        self.num_timesteps = 0
        self._num_timesteps_at_start = 0
        self._episode_num = 0
        self.seed = seed
        self.start_time = 0.0
        self.learning_rate = learning_rate
        self._last_obs = None
        self._stats_window_size = stats_window_size
        self.ep_info_buffer = deque(maxlen=self._stats_window_size)
        self._n_updates = 0

        self.observation_space = env.observation_space
        self.action_space = env.action_space
        self.env = env

        self.n_steps = None
        self.gamma = gamma
        self.ent_coef = ent_coef
        self.max_grad_norm = max_grad_norm
        self.log_dict = {}

        self.set_random_seed(self.seed)
        self.buffer_class = buffer_class
        self.buffer_kwargs = {} if buffer_kwargs is None else buffer_kwargs
        self.buffer = self.buffer_class(
            device=self.device,
            gamma=self.gamma,
            **self.buffer_kwargs,
        )
        self.policy_class = policy_class
        self.policy = self.policy_class(
            self.observation_space, self.action_space, self.learning_rate, **self.policy_kwargs
        )
        self.policy = self.policy.to(self.device)

    def _update_info_buffer(self, info: Dict[str, Any]) -> None:
        # Collect statistics
        assert self.ep_info_buffer is not None

        ep_info = info.get("episode")
        if ep_info is not None:
            self.ep_info_buffer.append(ep_info)

    def set_random_seed(self, seed: Optional[int] = None) -> None:
        if seed is None:
            return
        set_seed_everywhere(seed, using_cuda=self.device.type == torch.device("cuda").type)
        self.action_space.seed(seed)
        self.observation_space.seed(seed)

    def collect_rollouts(
            self,
            env,
            buffer: Buffer,
    ):
        self.policy.set_training_mode(False)
        self._last_obs, _ = self.env.reset()
        self._last_obs = np.array(self._last_obs)
        assert self._last_obs is not None, "No previous observation was provided"

        buffer.reset()
        terminated = False
        while not terminated:
            with torch.no_grad():
                obs_tensor = torch.as_tensor(self._last_obs, device=self.device)
                action = self.policy(obs_tensor.unsqueeze(0))['action']
            action = action.item()
            new_obs, reward, terminated, truncated, info = env.step(action)
            assert not truncated, 'Episode truncation must be off as we want to use Monte Carlo estimation'

            self.num_timesteps += 1
            self._episode_num += int(terminated)
            buffer.add(
                self._last_obs,
                action,
                reward,
            )

            self._last_obs = np.array(new_obs)
            self._update_info_buffer(info)

        buffer.compute_returns()

    def train(self) -> None:
        self.policy.set_training_mode(True)

        rollout_data = self.buffer.get()
        actions = rollout_data.actions.long()
        policy_output = self.policy.evaluate_actions(rollout_data.observations, actions)
        log_prob = policy_output['log_prob']
        entropy = policy_output['entropy']
        returns = rollout_data.returns

        # Policy gradient loss
        policy_loss = -(returns * log_prob).mean()

        # Entropy loss
        entropy = torch.mean(entropy)
        entropy_loss = -self.ent_coef * entropy

        loss = policy_loss + entropy_loss

        # Optimization step
        self.policy.optimizer.zero_grad()
        loss.backward()
        grad_norm = torch.nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
        self.policy.optimizer.step()

        self._n_updates += 1

        self.log_dict = dict([
            ("train/entropy_loss", entropy_loss.item()), ("train/entropy", entropy.item()),
            ("train/policy_gradient_loss", policy_loss.item()), ("train/loss", loss.item()),
            ("train/grad_norm", grad_norm.item()), ("train/n_updates", self._n_updates)
        ])

    def get_current_mean_return(self) -> float:
        if len(self.ep_info_buffer) == 0:
            return -math.inf

        return np.mean(np.concatenate([ep_info["r"] for ep_info in self.ep_info_buffer])).item()

    def _dump_logs(self, iteration: int) -> None:
        assert self.ep_info_buffer is not None

        time_elapsed = max((time.time_ns() - self.start_time) / 1e9, sys.float_info.epsilon)
        fps = int((self.num_timesteps - self._num_timesteps_at_start) / time_elapsed)
        self.log_dict["time/iterations"] = iteration
        if len(self.ep_info_buffer) > 0 and len(self.ep_info_buffer[0]) > 0:
            self.log_dict["rollout/ep_rew_mean"] = self.get_current_mean_return()
            self.log_dict["rollout/ep_len_mean"] = np.mean(
                np.concatenate([ep_info["l"] for ep_info in self.ep_info_buffer])).item()

        self.log_dict["time/fps"] = fps
        self.log_dict["time/time_elapsed"] = int(time_elapsed)
        self.log_dict["global_step"] = self.num_timesteps
        self.log_dict["num_episodes"] = self._episode_num
        print(json.dumps(self.log_dict, sort_keys=True, indent=4))

        if WANDB_IS_AVAILABLE and wandb.run is not None:
            wandb.log(self.log_dict)

    def learn(
            self,
            max_timesteps: int,
            expected_return: float,
            log_interval: int = 1000,
            save_checkpoint_path: str = None,
            save_checkpoint_interval: int = 5000,
    ) -> None:
        assert self.env is not None

        self.start_time = time.time_ns()
        self.num_timesteps = 0
        self._episode_num = 0
        self._num_timesteps_at_start = 0
        log_interval = log_interval or math.inf
        if save_checkpoint_path is None or save_checkpoint_interval is None or not COLAB:
            save_checkpoint_interval = math.inf

        next_log_step = self.num_timesteps + log_interval
        next_save_step = self.num_timesteps + save_checkpoint_interval

        if self._last_obs is None:
            self._last_obs, _ = self.env.reset(seed=self.seed)

        iteration = 0
        while True:
            if self.get_current_mean_return() >= expected_return:
                print('Решено!')
                break

            if self.num_timesteps >= max_timesteps:
                print(f'Задача не решена за {max_timesteps} шагов')
                break

            self.collect_rollouts(self.env, self.buffer, )
            iteration += 1

            if self.num_timesteps >= next_log_step:
                assert self.ep_info_buffer is not None
                self._dump_logs(iteration)
                next_log_step += log_interval

            if self.num_timesteps >= next_save_step:
                next_save_step += save_checkpoint_interval
                checkpoint = {'policy': self.policy.state_dict(), 'optimizer': self.policy.optimizer.state_dict(),
                              'num_timesteps': self.num_timesteps, 'episode_num': self._episode_num,
                              'ep_info_buffer': self.ep_info_buffer}
                os.makedirs(save_checkpoint_path, exist_ok=True)
                torch.save(checkpoint, os.path.join(save_checkpoint_path, 'checkpoint.pt'))

            self.train()

# %%
def run_algorithm(algorithm_class, algorithm_kwargs, use_wandb, wandb_kwargs, learn_kwargs):
    env = make_env()
    model = algorithm_class(env, **algorithm_kwargs)
    if use_wandb:
        config = {}
        config.update(algorithm_kwargs)
        config.update(learn_kwargs)
        config.update(wandb_kwargs.get('config', {}))
        wandb_kwargs['config'] = config
        if wandb.run is not None:
            wandb.finish()

        wandb.init(**wandb_kwargs)

    model.learn(**learn_kwargs)
    if use_wandb:
        wandb.finish()

# %%
run_algorithm(
    algorithm_class=Reinforce,
    algorithm_kwargs=dict(seed=0, ),
    use_wandb=True,
    wandb_kwargs=dict(project='seminar_actor-critic', monitor_gym=True, name='reinforce'),
    learn_kwargs=dict(max_timesteps=50000, log_interval=1000, expected_return=2000, save_checkpoint_interval=1000,
                      save_checkpoint_path='/content/drive/My Drive/seminar_actor-critic/reinforce',)
)
# Out:
# Using cuda device
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: ulaelfray. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.19.1
# Run data is saved locally in <code>/content/wandb/run-20251027_205951-5jhnmau3</code>
# Syncing run <strong><a href='https://wandb.ai/ulaelfray/seminar_actor-critic/runs/5jhnmau3' target="_blank">reinforce</a></strong> to <a href='https://wandb.ai/ulaelfray/seminar_actor-critic' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/ulaelfray/seminar_actor-critic' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic</a>
#  View run at <a href='https://wandb.ai/ulaelfray/seminar_actor-critic/runs/5jhnmau3' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic/runs/5jhnmau3</a>
# {
#     "global_step": 1006,
#     "num_episodes": 3,
#     "rollout/ep_len_mean": 335.3333333333333,
#     "rollout/ep_rew_mean": -76.22675323486328,
#     "time/fps": 220,
#     "time/iterations": 3,
#     "time/time_elapsed": 4,
#     "train/entropy": 2.0789310932159424,
#     "train/entropy_loss": -0.0020789310801774263,
#     "train/grad_norm": 0.012465535663068295,
#     "train/loss": -0.21674232184886932,
#     "train/n_updates": 2,
#     "train/policy_gradient_loss": -0.21466338634490967
# }
# {
#     "global_step": 2193,
#     "num_episodes": 6,
#     "rollout/ep_len_mean": 365.5,
#     "rollout/ep_rew_mean": -68.12448120117188,
#     "time/fps": 180,
#     "time/iterations": 6,
#     "time/time_elapsed": 12,
#     "train/entropy": 2.0788679122924805,
#     "train/entropy_loss": -0.002078867983072996,
#     "train/grad_norm": 0.025441385805606842,
#     "train/loss": -0.5018985271453857,
#     "train/n_updates": 5,
#     "train/policy_gradient_loss": -0.49981966614723206
# }
# {
#     "global_step": 4293,
#     "num_episodes": 7,
#     "rollout/ep_len_mean": 613.2857142857143,
#     "rollout/ep_rew_mean": -54.66374969482422,
#     "time/fps": 224,
#     "time/iterations": 7,
#     "time/time_elapsed": 19,
#     "train/entropy": 2.076836347579956,
#     "train/entropy_loss": -0.002076836535707116,
#     "train/grad_norm": 0.018119189888238907,
#     "train/loss": -0.3258703947067261,
#     "train/n_updates": 6,
#     "train/policy_gradient_loss": -0.32379356026649475
# }
# {
#     "global_step": 4699,
#     "num_episodes": 8,
#     "rollout/ep_len_mean": 587.375,
#     "rollout/ep_rew_mean": -55.357566833496094,
#     "time/fps": 233,
#     "time/iterations": 8,
#     "time/time_elapsed": 20,
#     "train/entropy": 2.074432134628296,
#     "train/entropy_loss": -0.0020744323264807463,
#     "train/grad_norm": 0.005937820766121149,
#     "train/loss": 0.02566981129348278,
#     "train/n_updates": 7,
#     "train/policy_gradient_loss": 0.027744242921471596
# }
# {
#     "global_step": 5211,
#     "num_episodes": 9,
#     "rollout/ep_len_mean": 579.0,
#     "rollout/ep_rew_mean": -59.53130340576172,
#     "time/fps": 244,
#     "time/iterations": 9,
#     "time/time_elapsed": 21,
#     "train/entropy": 2.0750622749328613,
#     "train/entropy_loss": -0.0020750623662024736,
#     "train/grad_norm": 0.03104863315820694,
#     "train/loss": -0.2880558669567108,
#     "train/n_updates": 8,
#     "train/policy_gradient_loss": -0.28598079085350037
# }
# {
#     "global_step": 6125,
#     "num_episodes": 12,
#     "rollout/ep_len_mean": 550.6,
#     "rollout/ep_rew_mean": -46.086456298828125,
#     "time/fps": 259,
#     "time/iterations": 12,
#     "time/time_elapsed": 23,
#     "train/entropy": 2.066114902496338,
#     "train/entropy_loss": -0.002066114917397499,
#     "train/grad_norm": 0.03470093011856079,
#     "train/loss": -0.4454176127910614,
#     "train/n_updates": 11,
#     "train/policy_gradient_loss": -0.44335150718688965
# }
# {
#     "global_step": 7001,
#     "num_episodes": 17,
#     "rollout/ep_len_mean": 270.8,
#     "rollout/ep_rew_mean": 726.15625,
#     "time/fps": 272,
#     "time/iterations": 17,
#     "time/time_elapsed": 25,
#     "train/entropy": 5.872422843822278e-05,
#     "train/entropy_loss": -5.872423258779236e-08,
#     "train/grad_norm": 0.002882734639570117,
#     "train/loss": 3.820510391960852e-05,
#     "train/n_updates": 16,
#     "train/policy_gradient_loss": 3.826382817351259e-05
# }
# {
#     "global_step": 8003,
#     "num_episodes": 23,
#     "rollout/ep_len_mean": 163.8,
#     "rollout/ep_rew_mean": 2101.619140625,
#     "time/fps": 282,
#     "time/iterations": 23,
#     "time/time_elapsed": 28,
#     "train/entropy": 3.0002549465280026e-05,
#     "train/entropy_loss": -3.000254977791883e-08,
#     "train/grad_norm": 0.00141418247949332,
#     "train/loss": 1.7505461073596962e-05,
#     "train/n_updates": 22,
#     "train/policy_gradient_loss": 1.7535463484819047e-05
# }
# Решено!
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>global_step</td><td>▁▂▄▅▅▆▇█</td></tr><tr><td>num_episodes</td><td>▁▂▂▃▃▄▆█</td></tr><tr><td>rollout/ep_len_mean</td><td>▄▄██▇▇▃▁</td></tr><tr><td>rollout/ep_rew_mean</td><td>▁▁▁▁▁▁▄█</td></tr><tr><td>time/fps</td><td>▄▁▄▅▅▆▇█</td></tr><tr><td>time/iterations</td><td>▁▂▂▃▃▄▆█</td></tr><tr><td>time/time_elapsed</td><td>▁▃▅▆▆▇▇█</td></tr><tr><td>train/entropy</td><td>██████▁▁</td></tr><tr><td>train/entropy_loss</td><td>▁▁▁▁▁▁██</td></tr><tr><td>train/grad_norm</td><td>▃▆▅▂▇█▁▁</td></tr><tr><td>train/loss</td><td>▅▁▃█▄▂██</td></tr><tr><td>train/n_updates</td><td>▁▂▂▃▃▄▆█</td></tr><tr><td>train/policy_gradient_loss</td><td>▅▁▃█▄▂██</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>global_step</td><td>8003</td></tr><tr><td>num_episodes</td><td>23</td></tr><tr><td>rollout/ep_len_mean</td><td>163.8</td></tr><tr><td>rollout/ep_rew_mean</td><td>2101.61914</td></tr><tr><td>time/fps</td><td>282</td></tr><tr><td>time/iterations</td><td>23</td></tr><tr><td>time/time_elapsed</td><td>28</td></tr><tr><td>train/entropy</td><td>3e-05</td></tr><tr><td>train/entropy_loss</td><td>-0.0</td></tr><tr><td>train/grad_norm</td><td>0.00141</td></tr><tr><td>train/loss</td><td>2e-05</td></tr><tr><td>train/n_updates</td><td>22</td></tr><tr><td>train/policy_gradient_loss</td><td>2e-05</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">reinforce</strong> at: <a href='https://wandb.ai/ulaelfray/seminar_actor-critic/runs/5jhnmau3' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic/runs/5jhnmau3</a><br> View project at: <a href='https://wandb.ai/ulaelfray/seminar_actor-critic' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251027_205951-5jhnmau3/logs</code>

# %% [markdown]
# # 2 REINFORCE с базовым уровнем
# Градиент стратагии зависит от величины отдачи. Однако отдача может быть очень шумной оценкой $Q ^ {\pi} (s, a)$, особенно в средах с отложенными или редкими вознаграждениями. Этот шум приводит к высокой дисперсии в оценках градиента, что влечёт за собой сильные изменения стратегии. При этом обучение становится нестабильным, а сходимость медленной. Одним из способов снижения дисперсии является использование базового уровня $b(s)$. Базовый уровень $b(s)$ не зависит от действий, поэтому вычитание из оценки $Q ^ {\pi} (s, a)$ не приводит к смещению оценки градиента.
#
# $$\nabla_\theta J(\theta) = \mathbb{E}_\pi [(G_t - b(s)) \nabla_\theta \ln \pi_\theta(a_t \vert s_t)]$$
#
# ## 2.1 REINFORCE с необучаемым базовым уровнем (средняя отдача)
# В некоторых случаях в качестве базового уровня достаточно использовать среднюю отдачу за предыдущие эпизоды. Даже такая простая эвристика может помочь стабилизировать процесс обучения на ранних этапах.

# %% [markdown]
# (3 балла)

# %%
class AverageReturnBuffer(Buffer):
    def __init__(self, gamma: float = 0.99, device: Union[torch.device, str] = "cpu"):
        super().__init__(gamma, device)
        self.returns = []
        self.average_return = 0.0
        self.count = 0

    def get_average_return(self):
        if self.count == 0:
            return 0.0
        return float(self.average_return)

    def compute_returns(self) -> None:
        R = 0
        episode_returns = []
        for reward in reversed(self.rewards):
            R = reward + self.gamma * R
            episode_returns.insert(0, R)
        self.returns = torch.tensor(episode_returns, dtype=torch.float32, device="cpu")

        mean_return = self.returns.mean().item()
        self.average_return = (self.average_return * self.count + mean_return) / (self.count + 1)
        self.count += 1

# %% [markdown]
# (1 балл)

# %%
class AverageReturnBaselineReinforce(Reinforce):
    def __init__(self, env: gym.Env, learning_rate: float = 2.5e-4, gamma: float = 0.99, ent_coef: float = 0.001,
                 max_grad_norm: float = 0.5, stats_window_size: int = 10, policy_class: Type[ReinforcePolicy] = ReinforcePolicy,
                 policy_kwargs: Optional[Dict[str, Any]] = None, buffer_class: Type[AverageReturnBuffer] = AverageReturnBuffer,
                 buffer_kwargs: Optional[Dict[str, Any]] = None, seed: Optional[int] = None,
                 device: Union[torch.device, str] = "cuda"):
        super().__init__(env, learning_rate, gamma, ent_coef, max_grad_norm, stats_window_size, policy_class, policy_kwargs,
                         buffer_class, buffer_kwargs, seed, device)

    def train(self) -> None:
        self.policy.set_training_mode(True)

        rollout_data = self.buffer.get()
        actions = rollout_data.actions.long()
        policy_output = self.policy.evaluate_actions(rollout_data.observations, actions)
        log_prob = policy_output['log_prob']
        entropy = policy_output['entropy']

        # Получаем среднюю отдачу
        baseline = self.buffer.get_average_return()

        # Посчитать отдачи с учётом базового уровня
        returns = rollout_data.returns - baseline


        # Policy gradient loss
        policy_loss = -(returns * log_prob).mean()

        # Entropy loss
        entropy = torch.mean(entropy)
        entropy_loss = -self.ent_coef * entropy

        loss = policy_loss + entropy_loss

        # Optimization step
        self.policy.optimizer.zero_grad()
        loss.backward()
        grad_norm = torch.nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
        self.policy.optimizer.step()

        self._n_updates += 1

        self.log_dict = dict([
            ("train/entropy_loss", entropy_loss.item()), ("train/entropy", entropy.item()),
            ("train/policy_gradient_loss", policy_loss.item()), ("train/loss", loss.item()),
            ("train/grad_norm", grad_norm.item()), ("train/n_updates", self._n_updates),
            ("train/baseline", baseline)
        ])

# %%
run_algorithm(
    algorithm_class=AverageReturnBaselineReinforce,
    algorithm_kwargs=dict(seed=0, ),
    use_wandb=True,
    wandb_kwargs=dict(project='seminar_actor-critic', monitor_gym=True, name='reinforce_simple-baseline'),
    learn_kwargs=dict(max_timesteps=50000, log_interval=1000, expected_return=2000, save_checkpoint_interval=1000,
                    save_checkpoint_path='/content/drive/My Drive/seminar_actor-critic/reinforce_simple-baseline')
)
# Out:
# Using cuda device
#  View run <strong style="color:#cdcd00">reinforce_simple-baseline</strong> at: <a href='https://wandb.ai/ulaelfray/seminar_actor-critic/runs/cszswo1l' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic/runs/cszswo1l</a><br> View project at: <a href='https://wandb.ai/ulaelfray/seminar_actor-critic' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251027_212044-cszswo1l/logs</code>
# Tracking run with wandb version 0.19.1
# Run data is saved locally in <code>/content/wandb/run-20251027_212218-0sblqqco</code>
# Syncing run <strong><a href='https://wandb.ai/ulaelfray/seminar_actor-critic/runs/0sblqqco' target="_blank">reinforce_simple-baseline</a></strong> to <a href='https://wandb.ai/ulaelfray/seminar_actor-critic' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/ulaelfray/seminar_actor-critic' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic</a>
#  View run at <a href='https://wandb.ai/ulaelfray/seminar_actor-critic/runs/0sblqqco' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic/runs/0sblqqco</a>
# {
#     "global_step": 1630,
#     "num_episodes": 4,
#     "rollout/ep_len_mean": 407.5,
#     "rollout/ep_rew_mean": -71.22537994384766,
#     "time/fps": 403,
#     "time/iterations": 4,
#     "time/time_elapsed": 4,
#     "train/baseline": -0.26718637347221375,
#     "train/entropy": 2.0786099433898926,
#     "train/entropy_loss": -0.0020786100067198277,
#     "train/grad_norm": 0.01795089989900589,
#     "train/loss": 0.09020025283098221,
#     "train/n_updates": 3,
#     "train/policy_gradient_loss": 0.0922788605093956
# }
# {
#     "global_step": 2028,
#     "num_episodes": 5,
#     "rollout/ep_len_mean": 405.6,
#     "rollout/ep_rew_mean": -76.8580093383789,
#     "time/fps": 380,
#     "time/iterations": 5,
#     "time/time_elapsed": 5,
#     "train/baseline": -0.21428302489221096,
#     "train/entropy": 2.079153060913086,
#     "train/entropy_loss": -0.002079153200611472,
#     "train/grad_norm": 0.019058307632803917,
#     "train/loss": 0.32828667759895325,
#     "train/n_updates": 4,
#     "train/policy_gradient_loss": 0.3303658366203308
# }
# {
#     "global_step": 3153,
#     "num_episodes": 6,
#     "rollout/ep_len_mean": 525.5,
#     "rollout/ep_rew_mean": -73.00260925292969,
#     "time/fps": 381,
#     "time/iterations": 6,
#     "time/time_elapsed": 8,
#     "train/baseline": -0.22140905112028123,
#     "train/entropy": 2.0790512561798096,
#     "train/entropy_loss": -0.0020790514536201954,
#     "train/grad_norm": 0.011310131289064884,
#     "train/loss": -0.06160668656229973,
#     "train/n_updates": 5,
#     "train/policy_gradient_loss": -0.05952763557434082
# }
# {
#     "global_step": 4102,
#     "num_episodes": 9,
#     "rollout/ep_len_mean": 455.77777777777777,
#     "rollout/ep_rew_mean": -71.02174377441406,
#     "time/fps": 374,
#     "time/iterations": 9,
#     "time/time_elapsed": 10,
#     "train/baseline": -0.19276309665292501,
#     "train/entropy": 2.0777475833892822,
#     "train/entropy_loss": -0.0020777476020157337,
#     "train/grad_norm": 0.01987445540726185,
#     "train/loss": -0.0495830662548542,
#     "train/n_updates": 8,
#     "train/policy_gradient_loss": -0.047505319118499756
# }
# {
#     "global_step": 5046,
#     "num_episodes": 12,
#     "rollout/ep_len_mean": 447.5,
#     "rollout/ep_rew_mean": -67.96821594238281,
#     "time/fps": 383,
#     "time/iterations": 12,
#     "time/time_elapsed": 13,
#     "train/baseline": -0.22094491598280994,
#     "train/entropy": 2.078399896621704,
#     "train/entropy_loss": -0.002078399993479252,
#     "train/grad_norm": 0.015934385359287262,
#     "train/loss": 0.16042733192443848,
#     "train/n_updates": 11,
#     "train/policy_gradient_loss": 0.16250573098659515
# }
# {
#     "global_step": 7397,
#     "num_episodes": 14,
#     "rollout/ep_len_mean": 576.7,
#     "rollout/ep_rew_mean": -47.824195861816406,
#     "time/fps": 391,
#     "time/iterations": 14,
#     "time/time_elapsed": 18,
#     "train/baseline": -0.213453244131345,
#     "train/entropy": 2.0781848430633545,
#     "train/entropy_loss": -0.0020781848579645157,
#     "train/grad_norm": 0.018035991117358208,
#     "train/loss": 0.09517482668161392,
#     "train/n_updates": 13,
#     "train/policy_gradient_loss": 0.09725300967693329
# }
# {
#     "global_step": 7752,
#     "num_episodes": 15,
#     "rollout/ep_len_mean": 572.4,
#     "rollout/ep_rew_mean": -43.02480697631836,
#     "time/fps": 384,
#     "time/iterations": 15,
#     "time/time_elapsed": 20,
#     "train/baseline": -0.1921876876481942,
#     "train/entropy": 2.076781749725342,
#     "train/entropy_loss": -0.0020767818205058575,
#     "train/grad_norm": 0.02030971273779869,
#     "train/loss": 0.5706455707550049,
#     "train/n_updates": 14,
#     "train/policy_gradient_loss": 0.5727223753929138
# }
# {
#     "global_step": 8223,
#     "num_episodes": 16,
#     "rollout/ep_len_mean": 507.0,
#     "rollout/ep_rew_mean": -34.621337890625,
#     "time/fps": 384,
#     "time/iterations": 16,
#     "time/time_elapsed": 21,
#     "train/baseline": -0.18901026199261348,
#     "train/entropy": 2.067971706390381,
#     "train/entropy_loss": -0.0020679717417806387,
#     "train/grad_norm": 0.05598408728837967,
#     "train/loss": 0.08718949556350708,
#     "train/n_updates": 15,
#     "train/policy_gradient_loss": 0.08925746381282806
# }
# {
#     "global_step": 9391,
#     "num_episodes": 19,
#     "rollout/ep_len_mean": 528.9,
#     "rollout/ep_rew_mean": -15.31884479522705,
#     "time/fps": 375,
#     "time/iterations": 19,
#     "time/time_elapsed": 25,
#     "train/baseline": -0.15248814783990383,
#     "train/entropy": 2.0225493907928467,
#     "train/entropy_loss": -0.0020225495100021362,
#     "train/grad_norm": 0.05309208482503891,
#     "train/loss": 0.17384617030620575,
#     "train/n_updates": 18,
#     "train/policy_gradient_loss": 0.17586871981620789
# }
# {
#     "global_step": 10063,
#     "num_episodes": 20,
#     "rollout/ep_len_mean": 577.0,
#     "rollout/ep_rew_mean": -2.295780897140503,
#     "time/fps": 378,
#     "time/iterations": 20,
#     "time/time_elapsed": 26,
#     "train/baseline": -0.1468790575469795,
#     "train/entropy": 2.0666067600250244,
#     "train/entropy_loss": -0.0020666068885475397,
#     "train/grad_norm": 0.043386369943618774,
#     "train/loss": 0.2037198543548584,
#     "train/n_updates": 19,
#     "train/policy_gradient_loss": 0.20578646659851074
# }
# {
#     "global_step": 11079,
#     "num_episodes": 22,
#     "rollout/ep_len_mean": 603.3,
#     "rollout/ep_rew_mean": 19.249279022216797,
#     "time/fps": 383,
#     "time/iterations": 22,
#     "time/time_elapsed": 28,
#     "train/baseline": -0.12303306765499569,
#     "train/entropy": 1.9842092990875244,
#     "train/entropy_loss": -0.0019842092879116535,
#     "train/grad_norm": 0.05752946436405182,
#     "train/loss": 0.591871976852417,
#     "train/n_updates": 21,
#     "train/policy_gradient_loss": 0.5938562154769897
# }
# {
#     "global_step": 12568,
#     "num_episodes": 25,
#     "rollout/ep_len_mean": 481.6,
#     "rollout/ep_rew_mean": 20.343334197998047,
#     "time/fps": 382,
#     "time/iterations": 25,
#     "time/time_elapsed": 32,
#     "train/baseline": -0.12144016257176797,
#     "train/entropy": 1.9969249963760376,
#     "train/entropy_loss": -0.001996925100684166,
#     "train/grad_norm": 0.11699677258729935,
#     "train/loss": 0.42459627985954285,
#     "train/n_updates": 24,
#     "train/policy_gradient_loss": 0.42659321427345276
# }
# {
#     "global_step": 13095,
#     "num_episodes": 27,
#     "rollout/ep_len_mean": 461.6,
#     "rollout/ep_rew_mean": 14.682668685913086,
#     "time/fps": 378,
#     "time/iterations": 27,
#     "time/time_elapsed": 34,
#     "train/baseline": -0.11266931289663681,
#     "train/entropy": 2.071277141571045,
#     "train/entropy_loss": -0.0020712772384285927,
#     "train/grad_norm": 0.028116736561059952,
#     "train/loss": 0.12219724804162979,
#     "train/n_updates": 26,
#     "train/policy_gradient_loss": 0.12426852434873581
# }
# {
#     "global_step": 14102,
#     "num_episodes": 32,
#     "rollout/ep_len_mean": 302.3,
#     "rollout/ep_rew_mean": 393.36480712890625,
#     "time/fps": 382,
#     "time/iterations": 32,
#     "time/time_elapsed": 36,
#     "train/baseline": 0.2723097626961047,
#     "train/entropy": 0.20864219963550568,
#     "train/entropy_loss": -0.00020864220277871937,
#     "train/grad_norm": 0.49744364619255066,
#     "train/loss": 1.7733376026153564,
#     "train/n_updates": 31,
#     "train/policy_gradient_loss": 1.7735462188720703
# }
# {
#     "global_step": 15014,
#     "num_episodes": 37,
#     "rollout/ep_len_mean": 191.9,
#     "rollout/ep_rew_mean": 1235.59765625,
#     "time/fps": 385,
#     "time/iterations": 37,
#     "time/time_elapsed": 38,
#     "train/baseline": 0.8868031583519446,
#     "train/entropy": 0.39662396907806396,
#     "train/entropy_loss": -0.0003966239746659994,
#     "train/grad_norm": 0.7841314077377319,
#     "train/loss": 0.7699102759361267,
#     "train/n_updates": 36,
#     "train/policy_gradient_loss": 0.7703068852424622
# }
# {
#     "global_step": 16032,
#     "num_episodes": 43,
#     "rollout/ep_len_mean": 173.9,
#     "rollout/ep_rew_mean": 1990.705810546875,
#     "time/fps": 388,
#     "time/iterations": 43,
#     "time/time_elapsed": 41,
#     "train/baseline": 2.0567637468200353,
#     "train/entropy": 8.47762858029455e-05,
#     "train/entropy_loss": -8.477628909986379e-08,
#     "train/grad_norm": 0.003926039673388004,
#     "train/loss": 4.576969149638899e-05,
#     "train/n_updates": 42,
#     "train/policy_gradient_loss": 4.5854467316530645e-05
# }
# Решено!
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>global_step</td><td>▁▁▂▂▃▄▄▄▅▅▆▆▇▇██</td></tr><tr><td>num_episodes</td><td>▁▁▁▂▂▃▃▃▄▄▄▅▅▆▇█</td></tr><tr><td>rollout/ep_len_mean</td><td>▅▅▇▆▅█▇▆▇██▆▆▃▁▁</td></tr><tr><td>rollout/ep_rew_mean</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▃▅█</td></tr><tr><td>time/fps</td><td>█▂▃▁▃▅▃▃▁▂▃▃▂▃▄▄</td></tr><tr><td>time/iterations</td><td>▁▁▁▂▂▃▃▃▄▄▄▅▅▆▇█</td></tr><tr><td>time/time_elapsed</td><td>▁▁▂▂▃▄▄▄▅▅▆▆▇▇▇█</td></tr><tr><td>train/baseline</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▃▄█</td></tr><tr><td>train/entropy</td><td>█████████████▂▂▁</td></tr><tr><td>train/entropy_loss</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▇▇█</td></tr><tr><td>train/grad_norm</td><td>▁▁▁▁▁▁▁▁▁▁▁▂▁▅█▁</td></tr><tr><td>train/loss</td><td>▂▂▁▁▂▂▃▂▂▂▃▃▂█▄▁</td></tr><tr><td>train/n_updates</td><td>▁▁▁▂▂▃▃▃▄▄▄▅▅▆▇█</td></tr><tr><td>train/policy_gradient_loss</td><td>▂▂▁▁▂▂▃▂▂▂▃▃▂█▄▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>global_step</td><td>16032</td></tr><tr><td>num_episodes</td><td>43</td></tr><tr><td>rollout/ep_len_mean</td><td>173.9</td></tr><tr><td>rollout/ep_rew_mean</td><td>1990.70581</td></tr><tr><td>time/fps</td><td>388</td></tr><tr><td>time/iterations</td><td>43</td></tr><tr><td>time/time_elapsed</td><td>41</td></tr><tr><td>train/baseline</td><td>2.05676</td></tr><tr><td>train/entropy</td><td>8e-05</td></tr><tr><td>train/entropy_loss</td><td>-0.0</td></tr><tr><td>train/grad_norm</td><td>0.00393</td></tr><tr><td>train/loss</td><td>5e-05</td></tr><tr><td>train/n_updates</td><td>42</td></tr><tr><td>train/policy_gradient_loss</td><td>5e-05</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">reinforce_simple-baseline</strong> at: <a href='https://wandb.ai/ulaelfray/seminar_actor-critic/runs/0sblqqco' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic/runs/0sblqqco</a><br> View project at: <a href='https://wandb.ai/ulaelfray/seminar_actor-critic' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251027_212218-0sblqqco/logs</code>

# %% [markdown]
# ## 2.2 REINFORCE с обучаемым базовым уровнем
# Чаще всего в качестве базового уровня применяется оценка функции полезности состояний $b(s) = v(s) = \mathbb{E}[G_t| s_t = s]$, получаемая с помощью нейросетевой аппроксимации. При этом величину $G_t - b(s_t)$ можно рассматривать как оценку функции преимущества (advantage) действия $a_t$ в состоянии $s_t$: $A(s_t, a_t) = Q(s_t, a_t) - V(s_t)$.
#
# #### Shared-encoder
# Модели стратегии и функции полезности могут обучаться в разных режимах — стратегия только on-policy (шаг обучения на текущей собранной подтраектории), а полезность on-policy или off-policy (шаг обучения на текущей подтраектории или на батче из replay buffer). Это с одной стороны привносит гибкость в обучение, с другой — усложняет его.
#
# Если обе модели обучаются on-policy, то имеет смысл объединить их сетки в одну и делать общий шаг обратного распространения ошибки. Однако, если они обучаются в разных режимах (и с разной частотой обновления), то велика вероятность, что их шаги обучения могут начать конфликтовать в случае общего тела — для такого варианта намного предпочтительнее разделить их на разные подсети (либо аккуратно настраивать гиперпарметры, чтобы стабилизировать обучение). В целом, рекомендуется использовать общий энкодер наблюдений, а далее как можно скорее разделять головы.

# %% [markdown]
# (2 балла)

# %%
class ValuePolicy(ReinforcePolicy):
    def __init__(self, observation_space: gym.Space, action_space: gym.Space, lr: float,
                 optimizer_class: Type[torch.optim.Optimizer] = torch.optim.RMSprop,
                 optimizer_kwargs: Dict[str, Any] = {'eps': 1e-5}):
        super().__init__(observation_space, action_space, lr, optimizer_class, optimizer_kwargs)

        self.value_net = nn.Sequential(
            nn.Linear(self.features_extractor.features_dim, 64),
            nn.ReLU(),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Linear(32, 1)
        )

    def evaluate_actions(self, obs: torch.Tensor, actions_taken: torch.Tensor) -> Dict[str, torch.Tensor]:
        features = self.extract_features(obs)

        logits = self.action_net(features)
        dist = torch.distributions.Categorical(logits=logits)

        log_prob = dist.log_prob(actions_taken)
        entropy = dist.entropy()

        values = self.value_net(features).squeeze(-1)

        return {
            "features": features,
            "log_prob": log_prob,
            "entropy": entropy,
            "values": values
        }

# %% [markdown]
# (1 балл)

# %%
class ValueBaselineReinforce(Reinforce):
    def __init__(self, env: gym.Env, learning_rate: float = 2.5e-4, gamma: float = 0.99, ent_coef: float = 0.001,
                 max_grad_norm: float = 0.5, stats_window_size: int = 10, policy_class: Type[ValuePolicy] = ValuePolicy,
                 policy_kwargs: Optional[Dict[str, Any]] = None, buffer_class: Type[Buffer] = Buffer,
                 buffer_kwargs: Optional[Dict[str, Any]] = None, seed: Optional[int] = None,
                 device: Union[torch.device, str] = "cuda", vf_coef: float = 0.5,):
        super().__init__(env, learning_rate, gamma, ent_coef, max_grad_norm, stats_window_size, policy_class,
                         policy_kwargs, buffer_class, buffer_kwargs, seed, device)
        self.vf_coef = vf_coef

    def train(self) -> None:
        self.policy.set_training_mode(True)

        rollout_data = self.buffer.get()
        actions = rollout_data.actions.long()
        policy_output = self.policy.evaluate_actions(rollout_data.observations, actions)
        log_prob = policy_output['log_prob']
        entropy = policy_output['entropy']
        values = policy_output['values']
        advantages = rollout_data.returns - values.detach()
        baseline = values.mean().item()

        # Policy gradient loss
        policy_loss = -(advantages * log_prob).mean()

        # Entropy loss
        entropy = torch.mean(entropy)
        entropy_loss = -self.ent_coef * entropy

        # Value loss с коэффициентов self.vf_coef
        value_loss = self.vf_coef * F.mse_loss(values, rollout_data.returns)

        loss = policy_loss + entropy_loss + value_loss

        # Optimization step
        self.policy.optimizer.zero_grad()
        loss.backward()
        grad_norm = torch.nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
        self.policy.optimizer.step()

        self._n_updates += 1

        self.log_dict = dict([
            ("train/entropy_loss", entropy_loss.item()), ("train/entropy", entropy.item()),
            ("train/policy_gradient_loss", policy_loss.item()), ("train/loss", loss.item()),
            ("train/grad_norm", grad_norm.item()), ("train/n_updates", self._n_updates),
            ("train/baseline", baseline), ("train/value_loss", value_loss.item())
        ])

# %%
run_algorithm(
    algorithm_class=ValueBaselineReinforce,
    algorithm_kwargs=dict(seed=0, ),
    use_wandb=True,
    wandb_kwargs=dict(project='seminar_actor-critic', monitor_gym=True, name='reinforce_value-baseline'),
    learn_kwargs=dict(max_timesteps=50000, log_interval=1000, expected_return=2000, save_checkpoint_interval=1000,
                    save_checkpoint_path='/content/drive/My Drive/seminar_actor-critic/reinforce_value-baseline')
)
# Out:
# Using cuda device
#  View run <strong style="color:#cdcd00">reinforce_batch-epoch-1</strong> at: <a href='https://wandb.ai/ulaelfray/seminar_actor-critic/runs/gkqdot32' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic/runs/gkqdot32</a><br> View project at: <a href='https://wandb.ai/ulaelfray/seminar_actor-critic' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251027_214145-gkqdot32/logs</code>
# Tracking run with wandb version 0.19.1
# Run data is saved locally in <code>/content/wandb/run-20251027_214449-qot0h11m</code>
# Syncing run <strong><a href='https://wandb.ai/ulaelfray/seminar_actor-critic/runs/qot0h11m' target="_blank">reinforce_value-baseline</a></strong> to <a href='https://wandb.ai/ulaelfray/seminar_actor-critic' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/ulaelfray/seminar_actor-critic' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic</a>
#  View run at <a href='https://wandb.ai/ulaelfray/seminar_actor-critic/runs/qot0h11m' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic/runs/qot0h11m</a>
# {
#     "global_step": 1684,
#     "num_episodes": 4,
#     "rollout/ep_len_mean": 421.0,
#     "rollout/ep_rew_mean": -30.591495513916016,
#     "time/fps": 456,
#     "time/iterations": 4,
#     "time/time_elapsed": 3,
#     "train/baseline": 0.034825753420591354,
#     "train/entropy": 2.078366756439209,
#     "train/entropy_loss": -0.002078366931527853,
#     "train/grad_norm": 0.7809134125709534,
#     "train/loss": -0.44525304436683655,
#     "train/n_updates": 3,
#     "train/policy_gradient_loss": -0.5425882935523987,
#     "train/value_loss": 0.09941359609365463
# }
# {
#     "global_step": 2204,
#     "num_episodes": 6,
#     "rollout/ep_len_mean": 367.3333333333333,
#     "rollout/ep_rew_mean": -9.719754219055176,
#     "time/fps": 430,
#     "time/iterations": 6,
#     "time/time_elapsed": 5,
#     "train/baseline": 0.032794076949357986,
#     "train/entropy": 2.013699531555176,
#     "train/entropy_loss": -0.0020136996172368526,
#     "train/grad_norm": 0.4770881235599518,
#     "train/loss": -0.15074491500854492,
#     "train/n_updates": 5,
#     "train/policy_gradient_loss": -0.21497884392738342,
#     "train/value_loss": 0.0662476196885109
# }
# {
#     "global_step": 3142,
#     "num_episodes": 9,
#     "rollout/ep_len_mean": 349.1111111111111,
#     "rollout/ep_rew_mean": 39.008113861083984,
#     "time/fps": 370,
#     "time/iterations": 9,
#     "time/time_elapsed": 8,
#     "train/baseline": 0.04910759627819061,
#     "train/entropy": 2.037336826324463,
#     "train/entropy_loss": -0.002037336817011237,
#     "train/grad_norm": 0.47215035557746887,
#     "train/loss": 0.04908144846558571,
#     "train/n_updates": 8,
#     "train/policy_gradient_loss": -0.010260539129376411,
#     "train/value_loss": 0.061379324644804
# }
# {
#     "global_step": 4038,
#     "num_episodes": 12,
#     "rollout/ep_len_mean": 346.7,
#     "rollout/ep_rew_mean": 63.766700744628906,
#     "time/fps": 383,
#     "time/iterations": 12,
#     "time/time_elapsed": 10,
#     "train/baseline": 0.04887384921312332,
#     "train/entropy": 2.0566492080688477,
#     "train/entropy_loss": -0.0020566494204103947,
#     "train/grad_norm": 0.30776429176330566,
#     "train/loss": -0.5422787070274353,
#     "train/n_updates": 11,
#     "train/policy_gradient_loss": -0.6479500532150269,
#     "train/value_loss": 0.1077280268073082
# }
# {
#     "global_step": 5057,
#     "num_episodes": 15,
#     "rollout/ep_len_mean": 306.7,
#     "rollout/ep_rew_mean": 46.64405059814453,
#     "time/fps": 395,
#     "time/iterations": 15,
#     "time/time_elapsed": 12,
#     "train/baseline": 0.03645985201001167,
#     "train/entropy": 2.0638036727905273,
#     "train/entropy_loss": -0.0020638038404285908,
#     "train/grad_norm": 0.43493449687957764,
#     "train/loss": -0.32679349184036255,
#     "train/n_updates": 14,
#     "train/policy_gradient_loss": -0.4478452503681183,
#     "train/value_loss": 0.12311557680368423
# }
# {
#     "global_step": 6139,
#     "num_episodes": 20,
#     "rollout/ep_len_mean": 268.9,
#     "rollout/ep_rew_mean": 265.6981201171875,
#     "time/fps": 401,
#     "time/iterations": 20,
#     "time/time_elapsed": 15,
#     "train/baseline": 0.25724855065345764,
#     "train/entropy": 1.006091833114624,
#     "train/entropy_loss": -0.0010060918284580112,
#     "train/grad_norm": 5.347128391265869,
#     "train/loss": 3.2649788856506348,
#     "train/n_updates": 19,
#     "train/policy_gradient_loss": 1.4285272359848022,
#     "train/value_loss": 1.8374578952789307
# }
# {
#     "global_step": 7143,
#     "num_episodes": 26,
#     "rollout/ep_len_mean": 182.8,
#     "rollout/ep_rew_mean": 1489.661376953125,
#     "time/fps": 407,
#     "time/iterations": 26,
#     "time/time_elapsed": 17,
#     "train/baseline": 3.096446990966797,
#     "train/entropy": 1.0250960258417763e-06,
#     "train/entropy_loss": -1.0250961191005104e-09,
#     "train/grad_norm": 166.55001831054688,
#     "train/loss": 17.686559677124023,
#     "train/n_updates": 25,
#     "train/policy_gradient_loss": -0.0,
#     "train/value_loss": 17.686559677124023
# }
# Решено!
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>global_step</td><td>▁▂▃▄▅▇█</td></tr><tr><td>num_episodes</td><td>▁▂▃▄▅▆█</td></tr><tr><td>rollout/ep_len_mean</td><td>█▆▆▆▅▄▁</td></tr><tr><td>rollout/ep_rew_mean</td><td>▁▁▁▁▁▂█</td></tr><tr><td>time/fps</td><td>█▆▁▂▃▄▄</td></tr><tr><td>time/iterations</td><td>▁▂▃▄▅▆█</td></tr><tr><td>time/time_elapsed</td><td>▁▂▃▅▅▇█</td></tr><tr><td>train/baseline</td><td>▁▁▁▁▁▂█</td></tr><tr><td>train/entropy</td><td>█████▄▁</td></tr><tr><td>train/entropy_loss</td><td>▁▁▁▁▁▅█</td></tr><tr><td>train/grad_norm</td><td>▁▁▁▁▁▁█</td></tr><tr><td>train/loss</td><td>▁▁▁▁▁▂█</td></tr><tr><td>train/n_updates</td><td>▁▂▃▄▅▆█</td></tr><tr><td>train/policy_gradient_loss</td><td>▁▂▃▁▂█▃</td></tr><tr><td>train/value_loss</td><td>▁▁▁▁▁▂█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>global_step</td><td>7143</td></tr><tr><td>num_episodes</td><td>26</td></tr><tr><td>rollout/ep_len_mean</td><td>182.8</td></tr><tr><td>rollout/ep_rew_mean</td><td>1489.66138</td></tr><tr><td>time/fps</td><td>407</td></tr><tr><td>time/iterations</td><td>26</td></tr><tr><td>time/time_elapsed</td><td>17</td></tr><tr><td>train/baseline</td><td>3.09645</td></tr><tr><td>train/entropy</td><td>0.0</td></tr><tr><td>train/entropy_loss</td><td>-0.0</td></tr><tr><td>train/grad_norm</td><td>166.55002</td></tr><tr><td>train/loss</td><td>17.68656</td></tr><tr><td>train/n_updates</td><td>25</td></tr><tr><td>train/policy_gradient_loss</td><td>0</td></tr><tr><td>train/value_loss</td><td>17.68656</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">reinforce_value-baseline</strong> at: <a href='https://wandb.ai/ulaelfray/seminar_actor-critic/runs/qot0h11m' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic/runs/qot0h11m</a><br> View project at: <a href='https://wandb.ai/ulaelfray/seminar_actor-critic' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251027_214449-qot0h11m/logs</code>

# %% [markdown]
# # 3 REINFORCE с разбиением на мини-батчи
# В предыдущих реализациях по данным одной собранной траетории стратегия обновлялась только один раз. Попробуем разбить траекторию на мини-батчи и обучаться на одной траектории в течение нескольких эпох. С одной стороны это должно привести к ускорению обучения, поскольку модели будут обновляться чаще. С другой стороны такая схема обучения отходит от on-policy режима.

# %%
class BatchedReturnBuffer(AverageReturnBuffer):
    def __init__(self, gamma: float = 0.99, device: Union[torch.device, str] = "cpu"):
        super().__init__(gamma, device)
        self.generator_ready = None

    def reset(self) -> None:
        super().reset()
        self.generator_ready = False

    def get(self, batch_size: Optional[Union[int, float]] = None) -> Generator[BufferSamples, None, None]:
        buffer_size = self.size()
        indices = np.random.permutation(buffer_size)
        if not self.generator_ready:
            self.observations = np.asarray(self.observations)
            self.actions = np.asarray(self.actions)
            self.returns = np.asarray(self.returns, dtype=np.float32)
            self.generator_ready = True

        if batch_size is None or math.isinf(batch_size):
            batch_size = buffer_size

        start_idx = 0
        while start_idx < buffer_size:
            yield self._get_samples(indices[start_idx: start_idx + batch_size])
            start_idx += batch_size

# %% [markdown]
# (3 балла)

# %%
class BatchedAverageReturnReinforce(Reinforce):
    def __init__(self, env: gym.Env, learning_rate: float = 2.5e-4, gamma: float = 0.99, ent_coef: float = 0.001,
                 max_grad_norm: float = 0.5, stats_window_size: int = 10, policy_class: Type[ReinforcePolicy] = ReinforcePolicy,
                 policy_kwargs: Optional[Dict[str, Any]] = None, buffer_class: Type[BatchedReturnBuffer] = BatchedReturnBuffer,
                 buffer_kwargs: Optional[Dict[str, Any]] = None, seed: Optional[int] = None,
                 device: Union[torch.device, str] = "cuda", batch_size: Union[int, float] = 64, n_epochs: int = 1):
        super().__init__(env, learning_rate, gamma, ent_coef, max_grad_norm, stats_window_size, policy_class, policy_kwargs,
                         buffer_class, buffer_kwargs, seed, device)
        self.batch_size = batch_size
        self.n_epochs = n_epochs

    def train(self) -> None:
        self.policy.set_training_mode(True)

        baseline = self.buffer.get_average_return()

        for epoch in range(self.n_epochs):
            batch_gen = self.buffer.get(batch_size=self.batch_size)
            for batch in batch_gen:
                actions = batch.actions.long()
                policy_output = self.policy.evaluate_actions(batch.observations, actions)
                log_prob = policy_output['log_prob']
                entropy = policy_output['entropy']

                baseline_tensor = torch.tensor(baseline, device=self.device, dtype=batch.returns.dtype)
                returns = batch.returns - baseline_tensor

                policy_loss = -(returns * log_prob).mean()

                entropy = torch.mean(entropy)
                entropy_loss = -self.ent_coef * entropy

                loss = policy_loss + entropy_loss

                self.policy.optimizer.zero_grad()
                loss.backward()
                grad_norm = torch.nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
                self.policy.optimizer.step()

                self._n_updates += 1

        self.log_dict = dict([
            ("train/entropy_loss", entropy_loss.item()), ("train/entropy", entropy.item()),
            ("train/policy_gradient_loss", policy_loss.item()), ("train/loss", loss.item()),
            ("train/grad_norm", grad_norm.item()), ("train/n_updates", self._n_updates),
            ("train/baseline", baseline)
        ])

# %% [markdown]
# ### Одна эпоха обучения

# %%
run_algorithm(
    algorithm_class=BatchedAverageReturnReinforce,
    algorithm_kwargs=dict(seed=0, batch_size=64, n_epochs=1),
    use_wandb=True,
    wandb_kwargs=dict(project='seminar_actor-critic', monitor_gym=True, name='reinforce_batch-epoch-1'),
    learn_kwargs=dict(max_timesteps=50000, log_interval=1000, expected_return=2000, save_checkpoint_interval=1000,
                    save_checkpoint_path='/content/drive/My Drive/seminar_actor-critic/reinforce_batch-epoch-1')
)
# Out:
# /usr/local/lib/python3.12/dist-packages/vizdoom/gymnasium_wrapper/base_gymnasium_env.py:84: UserWarning: Detected screen format CRCGCB. Only RGB24 and GRAY8 are supported in the Gymnasium wrapper. Forcing RGB24.
#   warnings.warn(
# Using cuda device
# Tracking run with wandb version 0.19.1
# Run data is saved locally in <code>/content/wandb/run-20251027_221730-x6hl9zaz</code>
# Syncing run <strong><a href='https://wandb.ai/ulaelfray/seminar_actor-critic/runs/x6hl9zaz' target="_blank">reinforce_batch-epoch-1</a></strong> to <a href='https://wandb.ai/ulaelfray/seminar_actor-critic' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/ulaelfray/seminar_actor-critic' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic</a>
#  View run at <a href='https://wandb.ai/ulaelfray/seminar_actor-critic/runs/x6hl9zaz' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic/runs/x6hl9zaz</a>
# {
#     "global_step": 3040,
#     "num_episodes": 4,
#     "rollout/ep_len_mean": 760.0,
#     "rollout/ep_rew_mean": -57.3502082824707,
#     "time/fps": 437,
#     "time/iterations": 4,
#     "time/time_elapsed": 6,
#     "train/baseline": -0.2810593744119008,
#     "train/entropy": 2.077448606491089,
#     "train/entropy_loss": -0.002077448647469282,
#     "train/grad_norm": 0.04723813757300377,
#     "train/loss": 0.07442223280668259,
#     "train/n_updates": 16,
#     "train/policy_gradient_loss": 0.07649967819452286
# }
# {
#     "global_step": 3368,
#     "num_episodes": 5,
#     "rollout/ep_len_mean": 673.6,
#     "rollout/ep_rew_mean": -63.17475509643555,
#     "time/fps": 407,
#     "time/iterations": 5,
#     "time/time_elapsed": 8,
#     "train/baseline": -0.2039728588424623,
#     "train/entropy": 2.0779266357421875,
#     "train/entropy_loss": -0.0020779266487807035,
#     "train/grad_norm": 0.06449364125728607,
#     "train/loss": 0.422035276889801,
#     "train/n_updates": 49,
#     "train/policy_gradient_loss": 0.4241132140159607
# }
# {
#     "global_step": 3705,
#     "num_episodes": 6,
#     "rollout/ep_len_mean": 617.5,
#     "rollout/ep_rew_mean": -61.54912185668945,
#     "time/fps": 393,
#     "time/iterations": 6,
#     "time/time_elapsed": 9,
#     "train/baseline": -0.21023796014487744,
#     "train/entropy": 2.0739970207214355,
#     "train/entropy_loss": -0.002073997166007757,
#     "train/grad_norm": 0.1812436729669571,
#     "train/loss": 0.018636850640177727,
#     "train/n_updates": 55,
#     "train/policy_gradient_loss": 0.02071084827184677
# }
# {
#     "global_step": 4156,
#     "num_episodes": 9,
#     "rollout/ep_len_mean": 461.77777777777777,
#     "rollout/ep_rew_mean": 189.24281311035156,
#     "time/fps": 390,
#     "time/iterations": 9,
#     "time/time_elapsed": 10,
#     "train/baseline": 0.2369974919129163,
#     "train/entropy": 0.021060321480035782,
#     "train/entropy_loss": -2.106032297888305e-05,
#     "train/grad_norm": 4.092453956604004,
#     "train/loss": 0.8014349341392517,
#     "train/n_updates": 66,
#     "train/policy_gradient_loss": 0.8014559745788574
# }
# {
#     "global_step": 5113,
#     "num_episodes": 15,
#     "rollout/ep_len_mean": 174.5,
#     "rollout/ep_rew_mean": 1282.9664306640625,
#     "time/fps": 397,
#     "time/iterations": 15,
#     "time/time_elapsed": 12,
#     "train/baseline": 2.726051147095859,
#     "train/entropy": 0.00048410132876597345,
#     "train/entropy_loss": -4.841013492296042e-07,
#     "train/grad_norm": 0.014298289082944393,
#     "train/loss": 0.0002469095925334841,
#     "train/n_updates": 83,
#     "train/policy_gradient_loss": 0.0002473937056493014
# }
# Решено!
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>global_step</td><td>▁▂▃▅█</td></tr><tr><td>num_episodes</td><td>▁▂▂▄█</td></tr><tr><td>rollout/ep_len_mean</td><td>█▇▆▄▁</td></tr><tr><td>rollout/ep_rew_mean</td><td>▁▁▁▂█</td></tr><tr><td>time/fps</td><td>█▄▁▁▂</td></tr><tr><td>time/iterations</td><td>▁▂▂▄█</td></tr><tr><td>time/time_elapsed</td><td>▁▃▅▆█</td></tr><tr><td>train/baseline</td><td>▁▁▁▂█</td></tr><tr><td>train/entropy</td><td>███▁▁</td></tr><tr><td>train/entropy_loss</td><td>▁▁▁██</td></tr><tr><td>train/grad_norm</td><td>▁▁▁█▁</td></tr><tr><td>train/loss</td><td>▂▅▁█▁</td></tr><tr><td>train/n_updates</td><td>▁▄▅▆█</td></tr><tr><td>train/policy_gradient_loss</td><td>▂▅▁█▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>global_step</td><td>5113</td></tr><tr><td>num_episodes</td><td>15</td></tr><tr><td>rollout/ep_len_mean</td><td>174.5</td></tr><tr><td>rollout/ep_rew_mean</td><td>1282.96643</td></tr><tr><td>time/fps</td><td>397</td></tr><tr><td>time/iterations</td><td>15</td></tr><tr><td>time/time_elapsed</td><td>12</td></tr><tr><td>train/baseline</td><td>2.72605</td></tr><tr><td>train/entropy</td><td>0.00048</td></tr><tr><td>train/entropy_loss</td><td>-0.0</td></tr><tr><td>train/grad_norm</td><td>0.0143</td></tr><tr><td>train/loss</td><td>0.00025</td></tr><tr><td>train/n_updates</td><td>83</td></tr><tr><td>train/policy_gradient_loss</td><td>0.00025</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">reinforce_batch-epoch-1</strong> at: <a href='https://wandb.ai/ulaelfray/seminar_actor-critic/runs/x6hl9zaz' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic/runs/x6hl9zaz</a><br> View project at: <a href='https://wandb.ai/ulaelfray/seminar_actor-critic' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251027_221730-x6hl9zaz/logs</code>

# %% [markdown]
# ### Две эпохи обучения

# %%
run_algorithm(
    algorithm_class=BatchedAverageReturnReinforce,
    algorithm_kwargs=dict(seed=0, batch_size=64, n_epochs=2),
    use_wandb=True,
    wandb_kwargs=dict(project='seminar_actor-critic', monitor_gym=True, name='reinforce_batch-epoch-2'),
    learn_kwargs=dict(max_timesteps=50000, log_interval=1000, expected_return=2000, save_checkpoint_interval=1000,
                    save_checkpoint_path='/content/drive/My Drive/seminar_actor-critic/reinforce_batch-epoch-2')
)
# Out:
# Using cuda device
# Tracking run with wandb version 0.19.1
# Run data is saved locally in <code>/content/wandb/run-20251027_221748-7tdwxhcv</code>
# Syncing run <strong><a href='https://wandb.ai/ulaelfray/seminar_actor-critic/runs/7tdwxhcv' target="_blank">reinforce_batch-epoch-2</a></strong> to <a href='https://wandb.ai/ulaelfray/seminar_actor-critic' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/ulaelfray/seminar_actor-critic' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic</a>
#  View run at <a href='https://wandb.ai/ulaelfray/seminar_actor-critic/runs/7tdwxhcv' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic/runs/7tdwxhcv</a>
# {
#     "global_step": 1192,
#     "num_episodes": 3,
#     "rollout/ep_len_mean": 397.3333333333333,
#     "rollout/ep_rew_mean": -93.69664764404297,
#     "time/fps": 408,
#     "time/iterations": 3,
#     "time/time_elapsed": 2,
#     "train/baseline": -0.24166381359100342,
#     "train/entropy": 2.00993013381958,
#     "train/entropy_loss": -0.00200993032194674,
#     "train/grad_norm": 0.11588096618652344,
#     "train/loss": 0.2663821876049042,
#     "train/n_updates": 20,
#     "train/policy_gradient_loss": 0.2683921158313751
# }
# {
#     "global_step": 3292,
#     "num_episodes": 4,
#     "rollout/ep_len_mean": 823.0,
#     "rollout/ep_rew_mean": -35.710357666015625,
#     "time/fps": 386,
#     "time/iterations": 4,
#     "time/time_elapsed": 8,
#     "train/baseline": -0.22133092085520426,
#     "train/entropy": 2.0418970584869385,
#     "train/entropy_loss": -0.0020418972708284855,
#     "train/grad_norm": 0.07694431394338608,
#     "train/loss": 0.0738072544336319,
#     "train/n_updates": 38,
#     "train/policy_gradient_loss": 0.07584915310144424
# }
# {
#     "global_step": 3584,
#     "num_episodes": 5,
#     "rollout/ep_len_mean": 716.8,
#     "rollout/ep_rew_mean": -51.612953186035156,
#     "time/fps": 374,
#     "time/iterations": 5,
#     "time/time_elapsed": 9,
#     "train/baseline": -0.15006197802722454,
#     "train/entropy": 2.067011594772339,
#     "train/entropy_loss": -0.002067011781036854,
#     "train/grad_norm": 0.054273709654808044,
#     "train/loss": 0.5397213697433472,
#     "train/n_updates": 104,
#     "train/policy_gradient_loss": 0.5417883992195129
# }
# {
#     "global_step": 4029,
#     "num_episodes": 7,
#     "rollout/ep_len_mean": 575.5714285714286,
#     "rollout/ep_rew_mean": 35.55411148071289,
#     "time/fps": 377,
#     "time/iterations": 7,
#     "time/time_elapsed": 10,
#     "train/baseline": -0.18235278502106667,
#     "train/entropy": 1.8113799095153809,
#     "train/entropy_loss": -0.0018113800324499607,
#     "train/grad_norm": 0.3806609809398651,
#     "train/loss": 0.07206785678863525,
#     "train/n_updates": 124,
#     "train/policy_gradient_loss": 0.07387923449277878
# }
# {
#     "global_step": 5032,
#     "num_episodes": 13,
#     "rollout/ep_len_mean": 384.0,
#     "rollout/ep_rew_mean": 1298.7022705078125,
#     "time/fps": 384,
#     "time/iterations": 13,
#     "time/time_elapsed": 13,
#     "train/baseline": 3.3643671354899802,
#     "train/entropy": 7.763179019093513e-05,
#     "train/entropy_loss": -7.76317961026507e-08,
#     "train/grad_norm": 0.0021393101196736097,
#     "train/loss": 3.0669492844026536e-05,
#     "train/n_updates": 160,
#     "train/policy_gradient_loss": 3.0747123673791066e-05
# }
# Решено!
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>global_step</td><td>▁▅▅▆█</td></tr><tr><td>num_episodes</td><td>▁▂▂▄█</td></tr><tr><td>rollout/ep_len_mean</td><td>▁█▆▄▁</td></tr><tr><td>rollout/ep_rew_mean</td><td>▁▁▁▂█</td></tr><tr><td>time/fps</td><td>█▃▁▂▃</td></tr><tr><td>time/iterations</td><td>▁▂▂▄█</td></tr><tr><td>time/time_elapsed</td><td>▁▅▅▆█</td></tr><tr><td>train/baseline</td><td>▁▁▁▁█</td></tr><tr><td>train/entropy</td><td>███▇▁</td></tr><tr><td>train/entropy_loss</td><td>▁▁▁▂█</td></tr><tr><td>train/grad_norm</td><td>▃▂▂█▁</td></tr><tr><td>train/loss</td><td>▄▂█▂▁</td></tr><tr><td>train/n_updates</td><td>▁▂▅▆█</td></tr><tr><td>train/policy_gradient_loss</td><td>▄▂█▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>global_step</td><td>5032</td></tr><tr><td>num_episodes</td><td>13</td></tr><tr><td>rollout/ep_len_mean</td><td>384</td></tr><tr><td>rollout/ep_rew_mean</td><td>1298.70227</td></tr><tr><td>time/fps</td><td>384</td></tr><tr><td>time/iterations</td><td>13</td></tr><tr><td>time/time_elapsed</td><td>13</td></tr><tr><td>train/baseline</td><td>3.36437</td></tr><tr><td>train/entropy</td><td>8e-05</td></tr><tr><td>train/entropy_loss</td><td>-0.0</td></tr><tr><td>train/grad_norm</td><td>0.00214</td></tr><tr><td>train/loss</td><td>3e-05</td></tr><tr><td>train/n_updates</td><td>160</td></tr><tr><td>train/policy_gradient_loss</td><td>3e-05</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">reinforce_batch-epoch-2</strong> at: <a href='https://wandb.ai/ulaelfray/seminar_actor-critic/runs/7tdwxhcv' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic/runs/7tdwxhcv</a><br> View project at: <a href='https://wandb.ai/ulaelfray/seminar_actor-critic' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251027_221748-7tdwxhcv/logs</code>
